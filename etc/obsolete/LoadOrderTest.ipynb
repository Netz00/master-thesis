# %% [markdown]
# # Loading order test

# %% [markdown]
# https://stackoverflow.com/q/73609173/12108610

# %%
# %%shell
#
# mkdir data
# cp $DATA/Kather_texture_2016_image_tiles_5000.png.zip data
# unzip data/Kather_texture_2016_image_tiles_5000.png.zip -d . && rm data/Kather_texture_2016_image_tiles_5000.png.zip

# %%
batch_size = 25  # 5000 / 25 = 200

train_ds, validation_ds = keras.utils.image_dataset_from_directory(
    "data/Kather_texture_2016_image_tiles_5000/",
    labels="inferred",
    label_mode="int",
    # class_names=None,
    color_mode="rgb",
    batch_size=batch_size,
    image_size=(150, 150),
    shuffle=True,
    seed=123,
    validation_split=0.95, # 0.3,
    subset="both",
    crop_to_aspect_ratio=False
)

# %%
val_batches = validation_ds.cardinality()                 # 70 %
test_ds = validation_ds.take((2*val_batches) // 3)        # 20 %
validation_ds = validation_ds.skip((2*val_batches) // 3)  # 10 %

# https://stackoverflow.com/a/74609848/12108610

# %%
y_test = np.concatenate([y_test for x, y_test in test_ds], axis = 0)
y_test1 = np.concatenate([y_test for x, y_test in test_ds], axis = 0)
print(y_test == y_test1)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
train_ds2, validation_ds2 = keras.utils.image_dataset_from_directory(
    "data/Kather_texture_2016_image_tiles_5000/",
    labels="inferred",
    label_mode="int",
    # class_names=None,
    color_mode="rgb",
    batch_size=25, # 5000 / 25 = 200
    image_size=(150, 150),
    shuffle=True,
    seed=123,
    validation_split=0.3,
    subset="both",
    crop_to_aspect_ratio=False
)
# Out:
# Found 5000 files belonging to 8 classes.
# Using 3500 files for training.
# Using 1500 files for validation.

# %%
val_batches = validation_ds2.cardinality()                 # 70 %
test_ds2 = validation_ds2.take((2*val_batches) // 3)        # 20 %
validation_ds2 = validation_ds2.skip((2*val_batches) // 3)  # 10 %

# %%
y_test2 = np.concatenate([y_test for x, y_test in test_ds2], axis = 0)
print(y_test == y_test2)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
# ...

# %%
train_ds3, validation_ds3 = keras.utils.image_dataset_from_directory(
    "data/Kather_texture_2016_image_tiles_5000/",
    labels="inferred",
    label_mode="int",
    # class_names=None,
    color_mode="rgb",
    batch_size=25, # 5000 / 25 = 200
    image_size=(150, 150),
    shuffle=True,
    seed=1234,
    validation_split=0.3,
    subset="both",
    crop_to_aspect_ratio=False
)
# Out:
# Found 5000 files belonging to 8 classes.
# Using 3500 files for training.
# Using 1500 files for validation.

# %%
val_batches = validation_ds3.cardinality()                 # 70 %
test_ds3 = validation_ds3.take((2*val_batches) // 3)        # 20 %
validation_ds3 = validation_ds3.skip((2*val_batches) // 3)  # 10 %

# %%
y_test3 = np.concatenate([y_test for x, y_test in test_ds3], axis = 0)
print(y_test == y_test3)
# Out:
# [ True False False False False False False False False False False False
#  False False False False  True False False False False  True False False
#  False False False False False False  True  True False False False False
#  False False False False  True False False False False False False False
#  False False  True False False False  True False False False False False
#  False False False False False False False False False False False  True
#  False False  True False False False False  True False False False False
#  False False False  True  True False False  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False  True False False False False False False
# ...
